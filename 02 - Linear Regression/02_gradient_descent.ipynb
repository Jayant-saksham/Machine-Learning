# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*47skUygd3tWf3yB9A10QHg.gif">

# %% [markdown]
# # Gradient Descent
# **Gradient descent is an iterative optimization algorithm for finding the local minimum of a function.**

# %% [markdown]
# <img src="https://editor.analyticsvidhya.com/uploads/631731_P7z2BKhd0R-9uyn9ThDasA.png">

# %% [markdown]
# # Learning Rate

# %% [markdown]
# <img src="data:image/jpeg;base64,...">

# %% [markdown]
# **How quickly we are moving is our Learning rate towards the answer**

# %% [markdown]
# # Loss function
# <img src="https://www.section.io/engineering-education/understanding-loss-functions-in-machine-learning/mean-squared-error.PNG">

# %%
import numpy as np
x = np.array([1,2,3,4,5])
y = np.array([5,7,9,11,13])

# %%
# We are considering loss function as 
# loss function = Sum((y - y')^2)/n
def gradient_descent(x, y):
    m_current = 0
    c_current = 0
    n = len(x)
    learning_rate = 0.0001
    iterations = 2000
    for i in range(iterations):
        y_predicted = m_current*x + c_current
        loss = (1/n) * sum([i**2 for i in (y-y_predicted)])
        md = -(2/n)*sum(x*(y - y_predicted))
        cd = -(2/n)*sum(y-y_predicted)
        m_current = m_current - learning_rate*md
        c_current = c_current - learning_rate*cd 
        print(f"Iteation {i} |  M = {m_current} and C = {c_current} Loss = {loss}")

# %%
gradient_descent(x=x, y=y)
# Out:
# Iteation 0 |  M = 0.006200000000000001 and C = 0.0018000000000000002 Loss = 89.0
# Iteation 1 |  M = 0.012385280000000002 and C = 0.00359592 Loss = 88.58369304
# Iteation 2 |  M = 0.018555874832000004 and C = 0.005387769648 Loss = 88.16935357626447
# Iteation 3 |  M = 0.024711819245580805 and C = 0.0071755585691712 Loss = 87.75697230888764
# Iteation 4 |  M = 0.030853147908099024 and C = 0.008959296365910018 Loss = 87.34653998192246
# Iteation 5 |  M = 0.03697989540488166 and C = 0.010738992617891976 Loss = 86.93804738317266
# Iteation 6 |  M = 0.04309209623942019 and C = 0.012514656882125469 Loss = 86.53148534398603
# Iteation 7 |  M = 0.04918978483356419 and C = 0.014286298693005392 Loss = 86.12684473904856
# Iteation 8 |  M = 0.055272995527714544 and C = 0.016053927562366652 Loss = 85.72411648617962
# Iteation 9 |  M = 0.06134176258101615 and C = 0.01781755297953755 Loss = 85.32329154612809
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x, y)
plt.show()
